# %%
f_fp = 1545
f_fn = 3651 

g_fp = 1197
g_fn = 3252 

l_fp = 2130
l_fn = 3521

# %%
print(f_fp / f_fn) , print(f_fn /f_fp)
# Out:
# 0.4231717337715694
# 2.363106796116505
# (None, None)

# %%
print(g_fp / g_fn) , print(g_fn/g_fp)
# Out:
# 0.36808118081180813
# 2.7167919799498748
# (None, None)

# %%
print(l_fp / l_fn) , print(l_fn/l_fp)
# Out:
# 0.6049417779040045
# 1.6530516431924882
# (None, None)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/home/allen/Galva/capstones/capstone2/src/explore/ready12_24_train.csv')

# %%
df
# Out:
#        Patient_ID_x  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  \
# 0            489652            6578        2005-09-10   4.0   0.0   0.0   0.0
# 1            489652            6532        2005-03-15   0.0   0.0   0.0   0.0
# 2            489652            6543        2005-11-26   4.0   0.0   0.0   0.0
# 3            489652            6580        2004-12-18   0.0   0.0   0.0   0.0
# 4            489652            6570        2005-05-01   0.0   0.0   0.0   0.0
# ...             ...             ...               ...   ...   ...   ...   ...
# 75273        489743            6538        2004-07-31   0.0   0.0   0.0   0.0
# 75274        514807            6528        2006-04-24   0.0   0.0   0.0   0.0
# 75275        522897            6529        2006-03-28   0.0   0.0   0.0   0.0
# 75276        527548            6529        2006-03-03   0.0   0.0   0.0   0.0
# 75277        504873            6543        2006-06-13   0.0   0.0   0.0   0.0
#
# ...
