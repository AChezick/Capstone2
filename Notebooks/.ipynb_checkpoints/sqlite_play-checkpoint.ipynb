# %%
import sqlite3

# %%
from pathlib import Path
Path('my_data.db').touch()

# %%
conn = sqlite3.connect('my_data.db')
c = conn.cursor()

# %%
#c.execute('''CREATE TABLE patient_profile (Patient_ID int, Online_Follower int,LinkedIn_Shared int, Twitter_Shared int, Facebook_Shared int, Income int, Education_Score int, Age int, First_Interaction text, City_Type text, Employer_Category text)''')

# %%
import pandas as pd
patient_profile = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Patient_Profile.csv')
patient_profile.to_sql('patient_profile', conn, if_exists='append',index=False)

# %%
c.execute('''
SELECT *
FROM patient_profile
LIMIT 10;

''').fetchall()
# Out:
# [(516956, 0, 0, 0, 0, 1, 90, 39, '18-Jun-03', None, 'Software Industry'),
#  (507733, 0, 0, 0, 0, 1, 'None', 40, '20-Jul-03', 'H', 'Software Industry'),
#  (508307, 0, 0, 0, 0, 3, 87, 46, '02-Nov-02', 'D', 'BFSI'),
#  (512612, 0, 0, 0, 0, 1, 75, 47, '02-Nov-02', 'D', 'Education'),
#  (521075, 0, 0, 0, 0, 3, 'None', 80, '24-Nov-02', 'H', 'Others'),
#  (502103, 0, 0, 0, 0, 'None', 'None', 'None', '06-Apr-03', None, None),
#  (528501, 0, 0, 0, 0, 'None', 'None', 'None', '26-Apr-03', None, None),
#  (519202, 0, 0, 0, 0, 'None', 'None', 'None', '05-Apr-03', None, None),
#  (521359, 0, 0, 0, 0, 'None', 'None', 'None', '10-Apr-03', 'F', None),
#  (487977, 0, 1, 1, 0, 4, 72, 58, '08-Jun-03', 'G', 'Technology')]

# %%
#c.execute('''CREATE TABLE first_health_camp_attended (Patient_ID int, Health_Camp_ID int, Donation int, Health_Score int)''')

# %%
first_health_camp=pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/First_Health_Camp_Attended.csv')
first_health_camp.to_sql('first_camp', conn, if_exists='append',index=False)
# Out:
# /home/allen/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
c.execute('''
SELECT *
FROM patient_profile p 
LEFT JOIN first_camp f 
ON p.Patient_ID = f.Patient_ID
''')
c.fetchall()
# Out:
# [(516956,
#   0,
#   0,
#   0,
#   0,
#   1,
#   90,
#   39,
#   '18-Jun-03',
#   None,
#   'Software Industry',
#   516956,
#   6561,
#   10,
#   0.563636364,
#   None),
#  (516956,
#   0,
#   0,
#   0,
#   0,
#   1,
#   90,
#   39,
#   '18-Jun-03',
#   None,
#   'Software Industry',
#   516956,
#   6561,
#   10,
#   0.563636364,
#   None),
#  (507733,
#   0,
#   0,
#   0,
#   0,
#   1,
#   'None',
#   40,
#   '20-Jul-03',
#   'H',
#   'Software Industry',
#   None,
#   None,
#   None,
#   None,
#   None),
#  (508307,
#   0,
#   0,
#   0,
#   0,
#   3,
#   87,
#   46,
#   '02-Nov-02',
#   'D',
#   'BFSI',
#   508307,
#   6537,
#   20,
#   0.056016598,
#   None),
#  (508307,
#   0,
#   0,
#   0,
#   0,
#   3,
#   87,
#   46,
#   '02-Nov-02',
#   'D',
#   'BFSI',
#   508307,
#   6537,
#   20,
#   0.056016598,
#   None),
#  (508307,
#   0,
#   0,
#   0,
#   0,
#   3,
#   87,
#   46,
#   '02-Nov-02',
#   'D',
#   'BFSI',
#   508307,
#   6543,
#   30,
#   0.160822249,
#   None),
# ...

# %%
pd.read_sql('''
SELECT *
FROM patient_profile p 
LEFT JOIN first_camp f 
ON p.Patient_ID = f.Patient_ID
''',conn)
# Out:
#         Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0           516956                0                0               0
# 1           516956                0                0               0
# 2           507733                0                0               0
# 3           508307                0                0               0
# 4           508307                0                0               0
# ...            ...              ...              ...             ...
# 139558      518600                0                0               0
# 139559      509515                0                0               0
# 139560      510713                0                0               0
# 139561      493667                0                0               0
# 139562      498051                0                0               0
#
#         Facebook_Shared Income Education_Score   Age First_Interaction  \
# ...

# %%
# c.execute('''CREATE TABLE third1 (Patient_ID int, Health_Camp_ID int, Number_of_stall_visited int,Last_Stall_Visited_Number int)''')  

third1=pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Third_Health_Camp_Attended.csv')
third1.to_sql('third1', conn, if_exists='append',index=False)

# %%
# pd.read_sql('''
# SELECT *
# FROM third1
# )
# ''',conn)

# %%
ones=pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/First_Health_Camp_Attended.csv')
twos = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Second_Health_Camp_Attended.csv')
three = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Third_Health_Camp_Attended.csv')

# %%
train = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Train.csv')
test = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/test.csv')

# %%
patient1 = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Patient_Profile.csv')

# %%
patient1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37633 entries, 0 to 37632
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         37633 non-null  int64
#  1   Online_Follower    37633 non-null  int64
#  2   LinkedIn_Shared    37633 non-null  int64
#  3   Twitter_Shared     37633 non-null  int64
#  4   Facebook_Shared    37633 non-null  int64
#  5   Income             37633 non-null  object
#  6   Education_Score    37633 non-null  object
#  7   Age                37633 non-null  object
#  8   First_Interaction  37633 non-null  object
#  9   City_Type          14249 non-null  object
#  10  Employer_Category  2840 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 3.2+ MB

# %%
# ones_,twos_,three_,train_,test_,patient1 = ones.columns, twos.columns,three.columns,train,columns,test.columns,patient1.columns

# %%
patient1['Patient_ID'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        516956
# 1        507733
# 2        508307
# 3        512612
# 4        521075
#           ...
# 37628    518600
# 37629    509515
# 37630    510713
# 37631    493667
# 37632    498051
# Name: Patient_ID, Length: 37633, dtype: int64>

# %%
twos['Health_Score'] = twos['Health Score'].values

# %%
twos = twos.drop('Health Score', axis=1)

# %%
twos.columns
# Out:
# Index(['Patient_ID', 'Health_Camp_ID', 'Health_Score'], dtype='object')

# %%
three = three.drop('Last_Stall_Visited_Number',axis=1)

# %%
health_camp_detail = pd.read_csv('/home/allen/Galva/capstones/capstone2/data/Train/Health_Camp_Detail.csv')

# %%
twos.to_csv('/home/allen/Galva/capstones/capstone2/data/Train/second.csv', index = False)

# %%
three.to_csv('/home/allen/Galva/capstones/capstone2/data/Train/third.csv', index = False)

# %%
health_camp_detail.columns
# Out:
# Index(['Health_Camp_ID', 'Camp_Start_Date', 'Camp_End_Date', 'Category1',
#        'Category2', 'Category3'],
#       dtype='object')

# %%
health_camp_detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Health_Camp_ID   65 non-null     int64
#  1   Camp_Start_Date  65 non-null     object
#  2   Camp_End_Date    65 non-null     object
#  3   Category1        65 non-null     object
#  4   Category2        65 non-null     object
#  5   Category3        65 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 3.2+ KB

# %%
health_camp_detail= health_camp_detail.drop('Category2', axis=1)

# %%
health_camp_detail= health_camp_detail.drop('Category3', axis=1)

# %%
three.columns
# Out:
# Index(['Patient_ID', 'Health_Camp_ID', 'Number_of_stall_visited'], dtype='object')

# %%
health_camp_detail.to_csv('/home/allen/Galva/capstones/capstone2/data/Train/camp_info.csv', index = False)

# %%
# Out:
# Index(['Health_Camp_ID', 'Camp_Start_Date', 'Camp_End_Date', 'Category1'], dtype='object')
